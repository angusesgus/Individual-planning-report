# %%
library(tidyverse)
library(repr)
library(tidymodels)
library(cowplot)

# %%
read_csv("https://raw.githubusercontent.com/angusesgus/Individual-planning-report/refs/heads/main/players.csv")
read_csv("https://raw.githubusercontent.com/angusesgus/Individual-planning-report/refs/heads/main/sessions.csv")
